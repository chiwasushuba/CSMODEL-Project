# %% [markdown]
# ## Family Income and Expenditure Survey 2012
# __Group 5 Members:__
# * Justine Valdes
# * Joshua Esleta
# * John Liong
# * Mark Musngi

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import ttest_ind

# %% [markdown]
# ## DataFrame
#
# Variables and Dictionaries are in the file "fies_2012_v1_metadata(dictionary)"

# %%
df = pd.read_csv("FIES PUF 2012 Vol.1.csv")
df.head()
# Out:
#    W_REGN      W_OID  W_SHSN  W_HCN  URB   RSTR     PSU  BWEIGHT     RFACT  \
# 0      14  101001000       2     25    2  21100  415052   138.25  200.6576
# 1      14  101001000       3     43    2  21100  415052   138.25  200.6576
# 2      14  101001000       4     62    2  21100  415052   138.25  200.6576
# 3      14  101001000       5     79    2  21100  415052   138.25  200.6576
# 4      14  101001000      10    165    2  21100  415052   138.25  200.6576
#
#    FSIZE  ...  PC_QTY  OVEN_QTY  MOTOR_BANCA_QTY  MOTORCYCLE_QTY   POP_ADJ  \
# 0    3.0  ...      01        01                                   0.946172
# 1   12.5  ...                01                               01  0.946172
# 2    2.0  ...                01                                   0.946172
# 3    4.0  ...                01                                   0.946172
# 4    5.0  ...                                                 01  0.946172
#
#        PCINC  NATPC  NATDC  REGDC  REGPC
# ...

# %%
df.shape
# Out:
# (40171, 119)

# %%
df
# Out:
#        W_REGN       W_OID  W_SHSN  W_HCN  URB   RSTR     PSU  BWEIGHT  \
# 0          14   101001000       2     25    2  21100  415052   138.25
# 1          14   101001000       3     43    2  21100  415052   138.25
# 2          14   101001000       4     62    2  21100  415052   138.25
# 3          14   101001000       5     79    2  21100  415052   138.25
# 4          14   101001000      10    165    2  21100  415052   138.25
# ...       ...         ...     ...    ...  ...    ...     ...      ...
# 40166      12  9804029001      18    568    1  22000  114062   271.25
# 40167      12  9804035000       1     25    2  22000  414067   271.25
# 40168      12  9804035000       2     51    2  22000  414067   271.25
# 40169      12  9804035000       3     75    2  22000  414067   271.25
# 40170      12  9804035000       4    102    2  22000  414067   271.25
#
#           RFACT  FSIZE  ...  PC_QTY  OVEN_QTY  MOTOR_BANCA_QTY  \
# 0      200.6576    3.0  ...      01        01
# ...

# %% [markdown]
# df.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40171 entries, 0 to 40170
# Columns: 119 entries, W_REGN to REGPC
# dtypes: float64(5), int64(92), object(22)
# memory usage: 36.5+ MB

# %% [markdown]
# ## GOAL TO GET THE Average Income Per region if urban or rural: (# of regions tagged rural or urban)
